# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#Función lineal

m = -1
b = 12

f = lambda x: x*m + b

x = np.linspace(-10,10, 100)
y = f(x)

fig, ax = plt.subplots()

ax.plot(x, y)
plt.grid()
