# %%
import pandas as pd
import numpy as np

# %%
dataframe = pd.read_csv('./resources/bestsellers with categories.csv', sep = ',')

# %%
dataframe.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8  \
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %%
dataframe = dataframe.drop('Genre', axis = 1)
dataframe.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8  \
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year
# 0  2016
# 1  2011

# %%
dataframe = dataframe.drop(0, axis=0)
dataframe.head(2)
# Out:
#                                       Name              Author  User Rating
# 1                        11/22/63: A Novel        Stephen King          4.6  \
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
#
#    Reviews  Price  Year
# 1     2052     22  2011
# 2    18979     15  2018

# %%
dataframe.drop([1,2,3], axis=0).head(2)
# Out:
#                                                 Name
# 4  5,000 Awesome Facts (About Everything!) (Natio...  \
# 5      A Dance with Dragons (A Song of Ice and Fire)
#
#                      Author  User Rating  Reviews  Price  Year
# 4  National Geographic Kids          4.8     7665     12  2019
# 5       George R. R. Martin          4.4    12643     11  2011

# %%
dataframe.drop(range(1,30), axis=0).head(2)
# Out:
#                                                  Name      Author
# 30  Barefoot Contessa Foolproof: Recipes You Can T...  Ina Garten  \
# 31  Barefoot Contessa, How Easy Is That?: Fabulous...  Ina Garten
#
#     User Rating  Reviews  Price  Year
# 30          4.8     1296     24  2012
# 31          4.7      615     21  2010

# %% [markdown]
# ## Add columns

# %%
dataframe = pd.read_csv('./resources/bestsellers with categories.csv', sep = ',')

# %%
#Creamos un arreglo del tamaño del axis 0
data_example = np.arange(0, dataframe.shape[0])

# %%
dataframe["nueva columna"] = np.nan

# %%
dataframe['Ejemplo_axis'] = data_example
dataframe
# Out:
#                                                   Name
# 0                        10-Day Green Smoothie Cleanse  \
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction  \
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# ## Add rows

# %%
dataframe.append([1,2,3,4,5,6,7,8,9])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 dataframe.append([1,2,3,4,5,6,7,8,9])
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'
