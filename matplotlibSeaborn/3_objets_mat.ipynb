# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 5, 20)
y = x**2

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.5, 0.9])
axes.plot(x,y, 'o--')

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.5, 0.9])
axes2 = fig.add_axes([0.146, 0.63, 0.3, 0.3])
axes.plot(x,y, 'o--')
axes2.plot(x,y, 'y:')

axes2.set_facecolor('gray')

fig.show()
# Out:
# /tmp/ipykernel_534/1015310136.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
